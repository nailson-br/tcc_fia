# %%
import pandas as pd

# %%
df = pd.read_csv('D:/repositorios/tcc_fia/fontes_apenas_planejamento/indicadores_teste.csv', sep=";", index_col=None)

# %%
df.head()
# Out:
#      SIGLA                      NOME CURTO                      NOME LONGO  \
# 0       UF  Código da Unidade da Federação  Código da Unidade da Federação
# 1      UFN    Nome da Unidade da Federação    Nome da Unidade da Federação
# 2  CODMUN6             Código do Município             Código do Município
# 3  CODMUN7             Código do Município             Código do Município
# 4  NOMEMUN               Nome do Município               Nome do município
#
#                                            DEFINIÇÃO
# 0  Código utilizado pelo IBGE para identificação ...
# 1                      Nome da Unidade da Federação.
# 2  Código utilizado pelo IBGE para identificação ...
# 3  Código utilizado pelo IBGE para identificação ...
# 4                                 Nome do município.

# %%
df['classe'] = ["identificação"] * 5 + ["População"] * 8 
                + ["Educação"] * 57 + ["Renda"] * 33 
                + ["Trabalho"] * 35 + ["Habitação"] * 8 
                + ["Educação"] * 2 + ["Habitação"] * 2 
                + ["Trabalho"] + ["Saúde"] * 2 
                + ["Trabalho"] * 4 + ["Habitação"] 
                + ["População"] * 36 + ["Trabalho"] * 4 
                + ["População"] * 33 + ["IDH"] * 6
# Out:
#   Cell In[13], line 2
#     + ["Educação"] * 57 + ["Renda"] * 33
#     ^
# IndentationError: unexpected indent

# %%
df.head(20)
# Out:
#            SIGLA                                  NOME CURTO  \
# 0             UF              Código da Unidade da Federação
# 1            UFN                Nome da Unidade da Federação
# 2        CODMUN6                         Código do Município
# 3        CODMUN7                         Código do Município
# 4        NOMEMUN                           Nome do Município
# 5        ESPVIDA                Esperança de vida ao nascer
# 6         FECTOT                   Taxa de fecundidade total
# 7          MORT1                        Mortalidade infantil
# 8          MORT5             Mortalidade até 5 anos de idade
# 9         RAZDEP                        Razão de dependência
# 10       SOBRE40  Probabilidade de sobrevivência até 40 anos
# 11       SOBRE60  Probabilidade de sobrevivência até 60 anos
# 12         T_ENV                      Taxa de envelhecimento
# 13  E_ANOSESTUDO               Expectativa de anos de estudo
# ...

# %%
df.tail(20)
# Out:
#               SIGLA                                         NOME CURTO  \
# 217          PESO65                       População de 65 anos ou mais
# 218       PESOM1014                           Mulheres de 10 a 14 anos
# 219       PESOM1517                           Mulheres de 15 a 17 anos
# 220        PESOM15M                        Mulheres de 15 anos ou mais
# 221        PESOM25M                        Mulheres de 25 anos ou mais
# 222         PESORUR                                    População rural
# 223         PESOTOT                                    População total
# 224         PESOURB                                   População urbana
# 225             PIA                       População de 10 anos ou mais
# 226         PIA1014                          População de 10 a 14 anos
# 227         PIA1517                          População de 15 a 17 anos
# 228          PIA18M                       População de 18 anos ou mais
# ...

# %%
["Identificação"] * 5
# Out:
# ['Identificação',
#  'Identificação',
#  'Identificação',
#  'Identificação',
#  'Identificação']
